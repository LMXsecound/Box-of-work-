# %%
pip install yfinance
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: yfinance in d:\anaconda\envs\tensorflow\lib\site-packages (0.2.52)
# Requirement already satisfied: pandas>=1.3.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda\envs\tensorflow\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: six>=1.9 in d:\anaconda\envs\tensorflow\lib\site-packages (from html5lib>=1.1->yfinance) (1.17.0)
# Requirement already satisfied: webencodings in d:\anaconda\envs\tensorflow\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests>=2.31->yfinance) (2024.12.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install ta
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: ta in d:\anaconda\envs\tensorflow\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in d:\anaconda\envs\tensorflow\lib\site-packages (from ta) (2.0.2)
# Requirement already satisfied: pandas in d:\anaconda\envs\tensorflow\lib\site-packages (from ta) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas->ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas->ta) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas->ta) (2025.1)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\tensorflow\lib\site-packages (from python-dateutil>=2.8.2->pandas->ta) (1.17.0)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import ta  # Technical Analysis library
# %pip install scikit-learn
from sklearn.preprocessing import MinMaxScaler
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: scikit-learn in d:\anaconda\envs\tensorflow\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in d:\anaconda\envs\tensorflow\lib\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Define the stock ticker (GOOG in this case)
ticker = 'GOOG'

# Download data from 2010-01-01 to the most recent available date
new_data = yf.download(ticker, start='2010-01-01', end='2024-01-01')

# Preview the new data
print(new_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           GOOG       GOOG       GOOG       GOOG       GOOG
# Date
# 2010-01-04  15.554351  15.622847  15.492058  15.559314   78541293
# 2010-01-05  15.485855  15.581402  15.425052  15.565022  120638494
# 2010-01-06  15.095476  15.532263  15.048323  15.532263  159744526
# 2010-01-07  14.744061  15.138659  14.708075  15.123768  257533695
# 2010-01-08  14.940614  14.971139  14.620220  14.691942  189680313

# %%
# Access the 'Close' column using the correct multi-level index
close_prices = new_data[('Close', ticker)]

# Check if it is a 1D pandas Series
print(close_prices.shape)
# Out:
# (3522,)

# %%
# Access the 'Close' column using the correct multi-level index
close_prices = new_data[('Close', ticker)]

# Step 3: Calculate technical indicators
# Calculate 20-period SMA (Simple Moving Average)
new_data[('SMA_20', '')] = new_data[('Close', ticker)].rolling(window=20).mean()

# Calculate 20-period EMA (Exponential Moving Average)
new_data[('EMA_20', '')] = new_data[('Close', ticker)].ewm(span=20, adjust=False).mean()

# Calculate 14-period RSI (Relative Strength Index)
new_data[('RSI', '')] = ta.momentum.RSIIndicator(close_prices, window=14).rsi()

# Calculate Bollinger Bands (Upper and Lower)
new_data[('Bollinger_Upper', '')] = new_data[('SMA_20', '')] + 2 * new_data[('Close', ticker)].rolling(window=20).std()
new_data[('Bollinger_Lower', '')] = new_data[('SMA_20', '')] - 2 * new_data[('Close', ticker)].rolling(window=20).std()

# Handle NaN values caused by rolling calculations (forward fill or drop)
new_data.ffill(inplace=True)

new_data.dropna(inplace=True)  # Alternatively, drop rows with NaN values

# Preview the data with the new technical indicators
print(new_data.head())
# Out:
# Price           Close       High        Low       Open     Volume     SMA_20  \
# Ticker           GOOG       GOOG       GOOG       GOOG       GOOG
# Date
# 2010-02-01  13.228209  13.297450  13.160705  13.267421   90369462  14.302855
# 2010-02-02  13.181057  13.276355  13.093947  13.276355  164462143  14.184191
# 2010-02-03  13.421785  13.453553  13.109333  13.120253  120413655  14.080987
# 2010-02-04  13.073348  13.351799  13.043071  13.326983  135614418  13.979881
# 2010-02-05  13.185275  13.240121  12.966137  13.113553  126713179  13.901941
#
# Price          EMA_20        RSI Bollinger_Upper Bollinger_Lower
# Ticker
# Date
# 2010-02-01  14.129522  18.327846       15.841282       12.764429
# 2010-02-02  14.039192  17.854576       15.681743       12.686638
# 2010-02-03  13.980391  28.067268       15.482232       12.679742
# 2010-02-04  13.894006  23.510993       15.364630       12.595132
# 2010-02-05  13.826508  27.578003       15.281049       12.522834

# %%
# %pip install matplotlib

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(new_data['Close'], label='GOOG Close Price')
plt.plot(new_data['SMA_20'], label='SMA 20', linestyle='--')
plt.plot(new_data['Bollinger_Upper'], label='Bollinger Upper Band', linestyle='--')
plt.plot(new_data['Bollinger_Lower'], label='Bollinger Lower Band', linestyle='--')
plt.legend(loc='best')
plt.title('GOOG Stock Price and Technical Indicators')
plt.show()
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: matplotlib in d:\anaconda\envs\tensorflow\lib\site-packages (3.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.21.0)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\tensorflow\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
from sklearn.preprocessing import MinMaxScaler

# Define the columns to normalize
features_to_normalize = ['Open', 'High', 'Low', 'Close', 'Volume', 
                         'SMA_20', 'EMA_20', 'RSI', 'Bollinger_Upper', 'Bollinger_Lower']

# Create a MinMaxScaler instance
scaler = MinMaxScaler()

# Normalize the selected features
new_data[features_to_normalize] = scaler.fit_transform(new_data[features_to_normalize])

# Preview the normalized data
print(new_data.head())
# Out:
# Price          Close      High       Low      Open    Volume    SMA_20  \
# Ticker          GOOG      GOOG      GOOG      GOOG      GOOG
# Date
# 2010-02-01  0.017267  0.016512  0.017311  0.017015  0.151601  0.020169
# 2010-02-02  0.016928  0.016361  0.016829  0.017079  0.276115  0.019296
# 2010-02-03  0.018656  0.017622  0.016940  0.015967  0.202091  0.018536
# 2010-02-04  0.016155  0.016898  0.016462  0.017439  0.227636  0.017792
# 2010-02-05  0.016958  0.016104  0.015907  0.015920  0.212677  0.017218
#
# Price         EMA_20       RSI Bollinger_Upper Bollinger_Lower
# Ticker
# Date
# 2010-02-01  0.018927  0.006645        0.026435        0.016275
# 2010-02-02  0.018259  0.000000        0.025306        0.015691
# 2010-02-03  0.017823  0.143403        0.023894        0.015639
# 2010-02-04  0.017184  0.079425        0.023062        0.015005
# 2010-02-05  0.016685  0.136533        0.022470        0.014463

# %%
def create_sequences(data, sequence_length, target_column='Close'):
    X, y = [], []
    for i in range(sequence_length, len(data)):
        # Select the features (excluding 'Date' and target column)
        features = data.iloc[i-sequence_length:i].drop(columns=[target_column]).values
        X.append(features)
        y.append(data.iloc[i][target_column])
    return np.array(X), np.array(y)

# Set sequence length (e.g., 60 days)
sequence_length = 60

# Create sequences for the model (e.g., 'Close' as target)
X, y = create_sequences(new_data, sequence_length, target_column='Close')

# Check shapes of features and target
print(f"Features Shape: {X.shape}, Target Shape: {y.shape}")
# Out:
# Features Shape: (3443, 60, 9), Target Shape: (3443, 1)

# %%
from sklearn.model_selection import train_test_split

# Initial split into training+validation and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# Further split training+validation into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.18, random_state=42)  # 18% of 85% ≈ 15%

# Print shapes of the splits
print(f"Training Data: X_train={X_train.shape}, y_train={y_train.shape}")
print(f"Validation Data: X_val={X_val.shape}, y_val={y_val.shape}")
print(f"Testing Data: X_test={X_test.shape}, y_test={y_test.shape}")
# Out:
# Training Data: X_train=(2399, 60, 9), y_train=(2399, 1)
# Validation Data: X_val=(527, 60, 9), y_val=(527, 1)
# Testing Data: X_test=(517, 60, 9), y_test=(517, 1)

# %%
np.savez('processed_goog_data.npz', X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test, X_val=X_val, y_val=y_val)

# %%
# Load preprocessed data
import numpy as np
data = np.load('processed_goog_data.npz')
X_train = data['X_train']
X_test = data['X_test']
y_train = data['y_train']
y_test = data['y_test']
X_val = data['X_val']
y_val = data['y_val']

print(f"Data loaded successfully: X_train={X_train.shape}, X_test={X_test.shape}")
# Out:
# Data loaded successfully: X_train=(2399, 60, 9), X_test=(517, 60, 9)

# %%
# %pip install tensorflow tensorflow-addons optuna shap linformer
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: tensorflow in d:\anaconda\envs\tensorflow\lib\site-packages (2.18.0)
# Requirement already satisfied: tensorflow-addons in d:\anaconda\envs\tensorflow\lib\site-packages (0.22.0)
# Requirement already satisfied: optuna in d:\anaconda\envs\tensorflow\lib\site-packages (4.2.0)
# Requirement already satisfied: shap in d:\anaconda\envs\tensorflow\lib\site-packages (0.46.0)
# Requirement already satisfied: linformer in d:\anaconda\envs\tensorflow\lib\site-packages (0.2.3)
# Requirement already satisfied: tensorflow-intel==2.18.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (25.1.24)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.29.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: alembic>=1.5.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from optuna) (1.14.1)
# Requirement already satisfied: colorlog in d:\anaconda\envs\tensorflow\lib\site-packages (from optuna) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in d:\anaconda\envs\tensorflow\lib\site-packages (from optuna) (2.0.37)
# Requirement already satisfied: tqdm in d:\anaconda\envs\tensorflow\lib\site-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in d:\anaconda\envs\tensorflow\lib\site-packages (from optuna) (6.0.2)
# Requirement already satisfied: scipy in d:\anaconda\envs\tensorflow\lib\site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in d:\anaconda\envs\tensorflow\lib\site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in d:\anaconda\envs\tensorflow\lib\site-packages (from shap) (2.2.3)
# Requirement already satisfied: slicer==0.0.8 in d:\anaconda\envs\tensorflow\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in d:\anaconda\envs\tensorflow\lib\site-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in d:\anaconda\envs\tensorflow\lib\site-packages (from shap) (3.1.1)
# Requirement already satisfied: torch in d:\anaconda\envs\tensorflow\lib\site-packages (from linformer) (2.5.1)
# Requirement already satisfied: Mako in d:\anaconda\envs\tensorflow\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.8)
# Requirement already satisfied: greenlet!=0.4.17 in d:\anaconda\envs\tensorflow\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: colorama in d:\anaconda\envs\tensorflow\lib\site-packages (from tqdm->optuna) (0.4.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in d:\anaconda\envs\tensorflow\lib\site-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\anaconda\envs\tensorflow\lib\site-packages (from pandas->shap) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: filelock in d:\anaconda\envs\tensorflow\lib\site-packages (from torch->linformer) (3.17.0)
# Requirement already satisfied: networkx in d:\anaconda\envs\tensorflow\lib\site-packages (from torch->linformer) (3.2.1)
# Requirement already satisfied: jinja2 in d:\anaconda\envs\tensorflow\lib\site-packages (from torch->linformer) (3.1.5)
# Requirement already satisfied: fsspec in d:\anaconda\envs\tensorflow\lib\site-packages (from torch->linformer) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from torch->linformer) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from sympy==1.13.1->torch->linformer) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in d:\anaconda\envs\tensorflow\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in d:\anaconda\envs\tensorflow\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in d:\anaconda\envs\tensorflow\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\envs\tensorflow\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from jinja2->torch->linformer) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\anaconda\envs\tensorflow\lib\site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (8.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\envs\tensorflow\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.19.1)
# Requirement already satisfied: zipp>=3.20 in d:\anaconda\envs\tensorflow\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\envs\tensorflow\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers
from linformer import Linformer

# Define the TCN block
def TCN_Block(input_shape, num_filters=64, kernel_size=3, dilation_rates=[1, 2, 4, 8], dropout_rate=0.2):
    inputs = tf.keras.Input(shape=input_shape)
    x = inputs
    for rate in dilation_rates:
        x = layers.Conv1D(
            filters=num_filters,
            kernel_size=kernel_size,
            dilation_rate=rate,
            padding='causal',
            activation='relu',
            kernel_regularizer=regularizers.l2(1e-4)  # L2 Regularization
        )(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(dropout_rate)(x)
    return tf.keras.Model(inputs, x, name="TCN_Block")


# Define the optimized Transformer block using MultiHeadAttention
def Optimized_Transformer_Block(input_shape, num_heads=4, ff_dim=64, dropout_rate=0.2):
    inputs = tf.keras.Input(shape=input_shape)

    # Multi-head attention layer
    attention_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=input_shape[-1])(inputs, inputs)
    attention_output = layers.Dropout(dropout_rate)(attention_output)
    attention_output = layers.LayerNormalization()(attention_output + inputs)  # Residual connection

    # Feed-forward layer
    ff_output = layers.Dense(ff_dim, activation='relu')(attention_output)
    ff_output = layers.Dropout(dropout_rate)(ff_output)
    ff_output = layers.Dense(input_shape[-1])(ff_output)
    ff_output = layers.LayerNormalization()(ff_output + attention_output)  # Residual connection

    return tf.keras.Model(inputs, ff_output, name="Optimized_Transformer_Block")


def TCN_Transformer_Model(input_shape, tcn_filters=64, transformer_heads=4, transformer_ff_dim=64, dropout_rate=0.2):
    inputs = tf.keras.Input(shape=input_shape)

    # TCN Block
    tcn = TCN_Block(input_shape, num_filters=tcn_filters, dropout_rate=dropout_rate)(inputs)

    # Transformer Block
    transformer = Optimized_Transformer_Block(input_shape=(tcn.shape[1], tcn.shape[2]),
                                              num_heads=transformer_heads,
                                              ff_dim=transformer_ff_dim,
                                              dropout_rate=dropout_rate)(tcn)

    # Dense Layers for prediction
    x = layers.GlobalAveragePooling1D()(transformer)
    x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(1e-4))(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(1, activation='linear')(x)

    return tf.keras.Model(inputs, outputs, name="TCN_Transformer_Model")

# %%
# Define the input shape
input_shape = (60, 9)  # 60 time steps, 9 features

# Instantiate the model
model = TCN_Transformer_Model(input_shape=input_shape, 
                              tcn_filters=64, 
                              transformer_heads=4, 
                              transformer_ff_dim=64, 
                              dropout_rate=0.2)

# Compile the model
model.compile(optimizer='adam', 
              loss='mse', 
              metrics=['mae'])

# Summary of the model
model.summary()
# Out:
# Model: "TCN_Transformer_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60, 9)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ TCN_Block (Functional)          │ (None, 60, 64)         │        39,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Optimized_Transformer_Block     │ (None, 60, 64)         │        74,944 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling1d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling1D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 119,041 (465.00 KB)
#  Trainable params: 118,529 (463.00 KB)
#  Non-trainable params: 512 (2.00 KB)

# %%
history = model.fit(
    X_train, y_train,                  # Training data
    validation_data=(X_val, y_val),    # Validation data
    epochs=50,                         # Number of epochs
    batch_size=32,                     # Batch size
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5)
    ]
)
# Out:
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - loss: 0.0969 - mae: 0.1858 - val_loss: 0.2879 - val_mae: 0.4788 - learning_rate: 0.0010
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0368 - mae: 0.0749 - val_loss: 0.1359 - val_mae: 0.3048 - learning_rate: 0.0010
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0321 - mae: 0.0596 - val_loss: 0.1389 - val_mae: 0.3262 - learning_rate: 0.0010
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0319 - mae: 0.0608 - val_loss: 0.2175 - val_mae: 0.4027 - learning_rate: 0.0010
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0294 - mae: 0.0512 - val_loss: 0.1000 - val_mae: 0.2381 - learning_rate: 0.0010
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0282 - mae: 0.0487 - val_loss: 0.0769 - val_mae: 0.1952 - learning_rate: 0.0010
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0289 - mae: 0.0544 - val_loss: 0.0468 - val_mae: 0.1428 - learning_rate: 0.0010
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0260 - mae: 0.0454 - val_loss: 0.0328 - val_mae: 0.0867 - learning_rate: 0.0010
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0264 - mae: 0.0512 - val_loss: 0.0382 - val_mae: 0.1056 - learning_rate: 0.0010
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0247 - mae: 0.0461 - val_loss: 0.0391 - val_mae: 0.1201 - learning_rate: 0.0010
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0242 - mae: 0.0458 - val_loss: 0.0295 - val_mae: 0.0901 - learning_rate: 0.0010
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0244 - mae: 0.0510 - val_loss: 0.0308 - val_mae: 0.0920 - learning_rate: 0.0010
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.0215 - mae: 0.0425 - val_loss: 0.0269 - val_mae: 0.0836 - learning_rate: 0.0010
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.0212 - mae: 0.0441 - val_loss: 0.0200 - val_mae: 0.0504 - learning_rate: 0.0010
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0198 - mae: 0.0403 - val_loss: 0.0335 - val_mae: 0.1030 - learning_rate: 0.0010
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0189 - mae: 0.0402 - val_loss: 0.0239 - val_mae: 0.0773 - learning_rate: 0.0010
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0184 - mae: 0.0394 - val_loss: 0.0186 - val_mae: 0.0536 - learning_rate: 0.0010
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0173 - mae: 0.0389 - val_loss: 0.0161 - val_mae: 0.0373 - learning_rate: 0.0010
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0169 - mae: 0.0398 - val_loss: 0.0167 - val_mae: 0.0461 - learning_rate: 0.0010
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0162 - mae: 0.0407 - val_loss: 0.0137 - val_mae: 0.0251 - learning_rate: 0.0010
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0155 - mae: 0.0397 - val_loss: 0.0147 - val_mae: 0.0454 - learning_rate: 0.0010
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0146 - mae: 0.0386 - val_loss: 0.0136 - val_mae: 0.0417 - learning_rate: 0.0010
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0140 - mae: 0.0391 - val_loss: 0.0172 - val_mae: 0.0539 - learning_rate: 0.0010
# Epoch 24/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0142 - mae: 0.0419 - val_loss: 0.0124 - val_mae: 0.0409 - learning_rate: 0.0010
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0127 - mae: 0.0374 - val_loss: 0.0117 - val_mae: 0.0405 - learning_rate: 0.0010
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0122 - mae: 0.0368 - val_loss: 0.0140 - val_mae: 0.0525 - learning_rate: 0.0010
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0120 - mae: 0.0374 - val_loss: 0.0098 - val_mae: 0.0303 - learning_rate: 0.0010
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0114 - mae: 0.0378 - val_loss: 0.0116 - val_mae: 0.0522 - learning_rate: 0.0010
# Epoch 29/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0112 - mae: 0.0411 - val_loss: 0.0106 - val_mae: 0.0453 - learning_rate: 0.0010
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0104 - mae: 0.0385 - val_loss: 0.0139 - val_mae: 0.0492 - learning_rate: 0.0010
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0097 - mae: 0.0370 - val_loss: 0.0140 - val_mae: 0.0569 - learning_rate: 0.0010
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0098 - mae: 0.0379 - val_loss: 0.0073 - val_mae: 0.0238 - learning_rate: 0.0010
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0092 - mae: 0.0376 - val_loss: 0.0084 - val_mae: 0.0348 - learning_rate: 0.0010
# Epoch 34/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0086 - mae: 0.0354 - val_loss: 0.0106 - val_mae: 0.0494 - learning_rate: 0.0010
# Epoch 35/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0088 - mae: 0.0396 - val_loss: 0.0071 - val_mae: 0.0320 - learning_rate: 0.0010
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0079 - mae: 0.0369 - val_loss: 0.0069 - val_mae: 0.0292 - learning_rate: 0.0010
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0077 - mae: 0.0359 - val_loss: 0.0074 - val_mae: 0.0336 - learning_rate: 0.0010
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0076 - mae: 0.0376 - val_loss: 0.0074 - val_mae: 0.0415 - learning_rate: 0.0010
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0071 - mae: 0.0366 - val_loss: 0.0072 - val_mae: 0.0455 - learning_rate: 0.0010
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0070 - mae: 0.0382 - val_loss: 0.0058 - val_mae: 0.0334 - learning_rate: 0.0010
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0065 - mae: 0.0352 - val_loss: 0.0060 - val_mae: 0.0328 - learning_rate: 0.0010
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0065 - mae: 0.0382 - val_loss: 0.0046 - val_mae: 0.0238 - learning_rate: 0.0010
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0070 - mae: 0.0408 - val_loss: 0.0054 - val_mae: 0.0328 - learning_rate: 0.0010
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mae: 0.0360 - val_loss: 0.0047 - val_mae: 0.0317 - learning_rate: 0.0010
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0059 - mae: 0.0375 - val_loss: 0.0050 - val_mae: 0.0373 - learning_rate: 0.0010
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0058 - mae: 0.0360 - val_loss: 0.0052 - val_mae: 0.0295 - learning_rate: 0.0010
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0056 - mae: 0.0357 - val_loss: 0.0050 - val_mae: 0.0382 - learning_rate: 0.0010
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0052 - mae: 0.0340 - val_loss: 0.0041 - val_mae: 0.0282 - learning_rate: 5.0000e-04
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0051 - mae: 0.0341 - val_loss: 0.0036 - val_mae: 0.0255 - learning_rate: 5.0000e-04
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0047 - mae: 0.0321 - val_loss: 0.0042 - val_mae: 0.0374 - learning_rate: 5.0000e-04

# %%
# Evaluate the model
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Mean Absolute Error: {test_mae}")
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034 - mae: 0.0238
# Test Loss: 0.0033734997268766165
# Test Mean Absolute Error: 0.023612793534994125

# %%
import matplotlib.pyplot as plt

# Make predictions
y_pred = model.predict(X_test)

# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.plot(y_test, label="Actual", color='blue')
plt.plot(y_pred, label="Predicted", color='orange')
plt.title("Actual vs Predicted Stock Prices")
plt.xlabel("Sample Index")
plt.ylabel("Stock Price")
plt.legend()
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
from sklearn.metrics import r2_score

# Calculate R² score
r2 = r2_score(y_test, y_pred)

print(f"R² Score: {r2}")
# Out:
# R² Score: 0.9882301097105085

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create an index for plotting
index = np.arange(len(y_test))

# Plot actual vs predicted values
plt.figure(figsize=(14, 8))  # Increase figure size for better visibility
plt.plot(index, y_test, label="Actual", color='blue', linewidth=1.5)
plt.plot(index, y_pred, label="Predicted", color='orange', linestyle='--', linewidth=1.5)

# Add gridlines
plt.grid(color='gray', linestyle='--', linewidth=0.5, alpha=0.7)

# Highlight differences
plt.fill_between(index, y_test.flatten(), y_pred.flatten(), color='gray', alpha=0.2, label="Error")

# Title and labels
plt.title("Actual vs Predicted Stock Prices", fontsize=16, fontweight='bold')
plt.xlabel("Sample Index", fontsize=12)
plt.ylabel("Stock Price (Normalized)", fontsize=12)

# Add legend
plt.legend(loc="upper right", fontsize=12)

# Zoom into a specific region (optional)
start, end = 50, 100  # Adjust range as needed
plt.xlim(start, end)  # Show detailed view of the specified range

# Display the plot
plt.tight_layout()
plt.show()
