# %%
import adata
import matplotlib as mpl

res_df = adata.stock.info.all_code()
print(res_df)
# Out:
#      stock_code short_name exchange   list_date
# 0        000001       平安银行       SZ  1991-04-03
# 1        000002        万科Ａ       SZ  1991-01-29
# 2        000003      PT金田A       SZ         NaN
# 3        000004       国华网安       SZ  1990-12-01
# 4        000005       ST星源       SZ  1990-12-10
# ...         ...        ...      ...         ...
# 5680     920108       宏海科技       BJ  2025-02-06
# 5681     920111       聚星科技       BJ  2024-11-11
# 5682     920116       星图测控       BJ  2025-01-02
# 5683     920118       太湖远大       BJ  2024-08-22
# 5684     920128       胜业电气       BJ  2024-11-29
#
# [5685 rows x 4 columns]

# %%
df =adata.stock.info.all_index_code()
print(df)
# Out:
#      index_code concept_code          name source
# 0        000917                      300公用   东方财富
# 1        000041                       上证公用   东方财富
# 2        000937                      800公用   东方财富
# 3        000995                       全指公用   东方财富
# 4        000079                       公用等权   东方财富
# ...         ...          ...           ...    ...
# 1068     483033                   深港通通信服务R   东方财富
# 1069     983034                深港通通信服务（港币）   东方财富
# 1070     483034               深港通通信服务R（港币）   东方财富
# 1071     399621                       深证电信   东方财富
# 1072     399688                       深成电信   东方财富
#
# [1073 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']  # 可以根据实际安装的字体名称修改
plt.rcParams['axes.unicode_minus'] = False    # 解决负号显示为方块的问题
a=adata.stock.market.get_market_index(start_date='1990-01-01')
b=adata.stock.market.get_market(stock_code='000002')
b.plot(x='trade_date', y='close', kind='line',label='万科A')
a.plot(x='trade_date', y='close', kind='line', ax=plt.gca(), label='沪深300')
plt.legend()
